# %% [markdown]
# # Set up event generation
#
# Johann Brehmer, Kyle Cranmer, Marco Farina, Felix Kling, Duccio Pappadopulo, Josh Ruderman 2018

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import numpy as np
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
import logging

from madminer.core import MadMiner

logging.basicConfig(format='%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s', datefmt='%H:%M', level=logging.DEBUG)
# Out:
# 20:41 matplotlib.backends  DEBUG   backend module://ipykernel.pylab.backend_inline version unknown

# %%
base_dir = '/Users/johannbrehmer/work/projects/madminer/diboson_mining/'
mg_dir = '/Users/johannbrehmer/work/projects/madminer/MG5_aMC_v2_6_4/'

# %%
logging.basicConfig(
    format='%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s',
    datefmt='%H:%M',
    level=logging.INFO
)

for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %%
sample_dir = base_dir + 'data/samples/wgamma_sys/'
card_dir = base_dir + 'cards/wgamma/'
ufo_model_dir = card_dir + 'SMWgamma_UFO'
run_card_dir = card_dir + 'run_cards/'
mg_process_dir = base_dir + 'data/mg_processes/wgamma_sys/'
log_dir = base_dir + 'logs/wgamma_sys/'
temp_dir = base_dir + 'data/temp'

# %% [markdown]
# ## Load setup

# %%
mm = MadMiner()

mm.load(sample_dir + 'setup.h5')
# Out:
# 20:41 madminer.utils.inter INFO    HDF5 file does not contain is_reference field.
# 20:41 madminer.core        INFO    Found 2 parameters:
# 20:41 madminer.core        INFO       cWWW (LHA: dim6 1, maximal power in squared ME: (2,), range: (-0.01, 0.01))
# 20:41 madminer.core        INFO       cWWWtilde (LHA: dim6 2, maximal power in squared ME: (2,), range: (-0.01, 0.01))
# 20:41 madminer.core        INFO    Found 6 benchmarks:
# 20:41 madminer.core        INFO       sm: cWWW = 0.00e+00, cWWWtilde = 0.00e+00
# 20:41 madminer.core        INFO       morphing_basis_vector_1: cWWW = 3.58e-03, cWWWtilde = 8.37e-03
# 20:41 madminer.core        INFO       morphing_basis_vector_2: cWWW = -7.12e-03, cWWWtilde = 5.34e-03
# 20:41 madminer.core        INFO       morphing_basis_vector_3: cWWW = -8.14e-03, cWWWtilde = -6.48e-03
# 20:41 madminer.core        INFO       morphing_basis_vector_4: cWWW = 9.21e-03, cWWWtilde = 1.15e-03
# 20:41 madminer.core        INFO       morphing_basis_vector_5: cWWW = 3.40e-03, cWWWtilde = -7.55e-03
# 20:41 madminer.core        INFO    Found morphing setup with 6 components
# 20:41 madminer.core        INFO    Found systematics setup with 2 nuisance parameter groups
# 20:41 madminer.core        DEBUG     mu: 0.5,2
# 20:41 madminer.core        DEBUG     pdf: 90900

# %% [markdown]
# ## Set up MG folder, cards, scripts

# %%
n_run_cards = 10
n_runs_per_card = 2

run_card_filenames = []
for _ in range(n_runs_per_card):
    for i in range(n_run_cards):
        run_card_filenames.append(run_card_dir + 'run_card_' + str(i) + '.dat')
    run_card_filenames.append(run_card_dir + 'run_card_X.dat')
    
benchmarks = ['sm']

for x in run_card_filenames:
    print(x)
# Out:
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_0.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_1.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_2.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_3.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_4.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_5.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_6.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_7.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_8.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_9.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_X.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_0.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_1.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_2.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_3.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_4.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_5.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_6.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_7.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_8.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_9.dat
# /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_X.dat

# %%
mm.run_multiple(
    mg_directory=mg_dir,
    proc_card_file=card_dir + 'proc_card_mg5.dat',
    param_card_template_file=card_dir + 'param_card.dat',
    pythia8_card_file=card_dir + 'pythia8_card.dat',
    run_card_files=run_card_filenames,
    mg_process_directory=mg_process_dir,
    ufo_model_directory=ufo_model_dir,
    temp_directory=temp_dir,
    sample_benchmarks=benchmarks,
    is_background=False,
    only_prepare_script=True,
    #initial_command='source activate python2',
    log_directory=log_dir
)
# Out:
# 20:41 madminer.utils.inter INFO    Generating MadGraph process folder from /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/proc_card_mg5.dat at /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 0
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_0.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_0.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_0.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_0.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_0.dat
# 20:41 madminer.core        INFO      Log file:                run_0.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_0.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_0.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 1
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_1.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_1.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_1.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_1.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_1.dat
# 20:41 madminer.core        INFO      Log file:                run_1.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_1.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_1.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 2
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_2.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_2.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_2.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_2.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_2.dat
# 20:41 madminer.core        INFO      Log file:                run_2.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_2.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_2.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 3
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_3.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_3.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_3.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_3.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_3.dat
# 20:41 madminer.core        INFO      Log file:                run_3.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_3.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_3.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 4
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_4.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_4.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_4.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_4.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_4.dat
# 20:41 madminer.core        INFO      Log file:                run_4.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_4.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_4.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 5
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_5.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_5.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_5.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_5.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_5.dat
# 20:41 madminer.core        INFO      Log file:                run_5.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_5.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_5.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 6
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_6.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_6.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_6.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_6.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_6.dat
# 20:41 madminer.core        INFO      Log file:                run_6.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_6.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_6.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 7
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_7.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_7.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_7.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_7.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_7.dat
# 20:41 madminer.core        INFO      Log file:                run_7.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_7.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_7.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 8
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_8.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_8.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_8.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_8.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_8.dat
# 20:41 madminer.core        INFO      Log file:                run_8.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_8.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_8.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 9
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_9.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_9.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_9.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_9.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_9.dat
# 20:41 madminer.core        INFO      Log file:                run_9.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_9.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_9.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 10
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_X.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_10.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_10.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_10.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_10.dat
# 20:41 madminer.core        INFO      Log file:                run_10.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_10.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_10.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 11
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_0.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_11.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_11.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_11.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_11.dat
# 20:41 madminer.core        INFO      Log file:                run_11.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_11.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_11.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 12
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_1.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_12.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_12.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_12.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_12.dat
# 20:41 madminer.core        INFO      Log file:                run_12.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_12.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_12.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 13
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_2.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_13.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_13.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_13.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_13.dat
# 20:41 madminer.core        INFO      Log file:                run_13.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_13.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_13.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 14
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_3.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_14.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_14.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_14.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_14.dat
# 20:41 madminer.core        INFO      Log file:                run_14.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_14.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_14.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 15
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_4.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_15.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_15.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_15.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_15.dat
# 20:41 madminer.core        INFO      Log file:                run_15.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_15.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_15.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 16
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_5.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_16.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_16.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_16.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_16.dat
# 20:41 madminer.core        INFO      Log file:                run_16.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_16.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_16.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 17
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_6.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_17.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_17.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_17.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_17.dat
# 20:41 madminer.core        INFO      Log file:                run_17.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_17.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_17.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 18
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_7.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_18.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_18.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_18.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_18.dat
# 20:41 madminer.core        INFO      Log file:                run_18.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_18.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_18.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 19
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_8.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_19.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_19.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_19.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_19.dat
# 20:41 madminer.core        INFO      Log file:                run_19.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_19.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_19.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 20
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_9.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_20.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_20.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_20.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_20.dat
# 20:41 madminer.core        INFO      Log file:                run_20.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_20.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_20.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    Run 21
# 20:41 madminer.core        INFO      Sampling from benchmark: sm
# 20:41 madminer.core        INFO      Original run card:       /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/run_cards/run_card_X.dat
# 20:41 madminer.core        INFO      Original Pythia8 card:   /Users/johannbrehmer/work/projects/madminer/diboson_mining/cards/wgamma/pythia8_card.dat
# 20:41 madminer.core        INFO      Copied run card:         /madminer/cards/run_card_21.dat
# 20:41 madminer.core        INFO      Copied Pythia8 card:     /madminer/cards/pythia8_card_21.dat
# 20:41 madminer.core        INFO      Param card:              /madminer/cards/param_card_21.dat
# 20:41 madminer.core        INFO      Reweight card:           /madminer/cards/reweight_card_21.dat
# 20:41 madminer.core        INFO      Log file:                run_21.log
# 20:41 madminer.core        INFO    Creating param and reweight cards in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/param_card_21.dat, /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys///madminer/cards/reweight_card_21.dat
# 20:41 madminer.utils.inter INFO    Preparing script to run MadGraph and Pythia in /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys/
# 20:41 madminer.core        INFO    To generate events, please run:
#
#  /Users/johannbrehmer/work/projects/madminer/diboson_mining/data/mg_processes/wgamma_sys//madminer/run.sh [MG_directory] [MG_process_directory] [log_dir]
